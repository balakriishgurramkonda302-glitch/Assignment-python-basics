# %% [markdown]
# **1. What are data structures, and why are they important**

# %% [markdown]
# There are 4 data structures
#
# a.List
#
# b.Tuples
#
# c.Sets
#
# d.Dictionaries
#
#
#
# Imaprtance:
#
# Efficient data storage for number of heterogeneous data types to assign to single variable. Fast Data access can be easily done. Organizing the data very easily and access them. In Real time projects without these cant do anything.

# %% [markdown]
# **2.Explain the difference between mutable and immutable data types with examples**

# %% [markdown]
# Mutable: meaning itself indicates that it will change the data value assigned to variable and indexing is possible through this.
#
# Immutable: meaning itself indicates that it cannot change the data value assigned to variable and indexing is also not  possible through this.
#
# A=[1,2,3,4,5]
#
# A[1]=10
#
# A
#
# B=(11,12,13,14,15)
#
# B[2]=20
#
# B

# %% [markdown]
# **3.What are the main differences between lists and tuples in Python**

# %% [markdown]
# The main differences between tuples and Lists are based on mutability concept. List can able to mutable while the tuples are not.

# %% [markdown]
# **4.Describe how dictionaries store data**

# %% [markdown]
# Dictionaries will store the data in the form of key and value based data structure.
#
# Eg: c={'name':'Balu','age':34}
#
# Name and age are keys and Balu and 34 are the values.

# %% [markdown]
# **5.Why might you use a set instead of a list in Python**

# %% [markdown]
# The usage of set instead of List is mainly for immutable data types to be added.Cause in sets values cant be changed and ordered and duplicates not allowed in sets where you required fixed valuesto get the output.

# %% [markdown]
# **6.What is a string in Python, and how is it different from a list**

# %% [markdown]
# The collection of characters/letters is nothing but string and represents in single/double quotes, lists can store these strings inside of lists and can use it. Only letters be allowed and not editable.

# %% [markdown]
# **7.How do tuples ensure data integrity in Python**

# %% [markdown]
# a.Basically tuples are immutable data types
#
# b.Accidental data changes cannot be allowed
#
# c.tuples can used as dic keys also, Hashable for safe indexing.

# %% [markdown]
# **8.What is a hash table, and how does it relate to dictionaries in Python**

# %% [markdown]
# When we create dictionary internally converts will store keys into hash values(memory locations).Hash is converting keys into unique number and this number helps to find quickly the key.

# %% [markdown]
# **9.Can lists contain different data types in Python**

# %% [markdown]
# Yes, definitely it allows you to store heterogeneous values.

# %% [markdown]
# **10. Explain why strings are immutable in Python**

# %% [markdown]
# Strings are used to store in special locations in python called string internal pool.
#
# Reasons:
#
# For faster performance, Strings also used as keys in hash table. Memory optimization, security and consistency

# %% [markdown]
# **11. What advantages do dictionaries offer over lists for certain tasks**

# %% [markdown]
# a.fast look up the values with hash values
#
# b. Meaningful keys instead of Index
#
# c. Real world data and objects storing
#
# d. avoid duplicates
#
# Fast updates results

# %% [markdown]
# **12. Describe a scenario where using a tuple would be preferable over a list**

# %% [markdown]
# GPS location sendingà I f we want to send location to others we must use tuples, instead of lists and where the constant and the values u thought is not change, that place we used use tuples over lists.

# %% [markdown]
# **13.How do sets handle duplicate values in Python**

# %% [markdown]
# Sets have inbuilt feature called it does not allow duplicates even it is created.
#
# It does because of hash table(unique memory location ) internally to store the values.

# %% [markdown]
# **14.How does the “in” keyword work differently for lists and dictionaries**

# %% [markdown]
# In keyword checks the value not the index in lists, it becomes difficult when over a large number of values to get it check.
#
# In Keyword checks the keys and immediately provide the answer with help of hash table and over a large number of data values.

# %% [markdown]
# **15.Can you modify the elements of a tuple? Explain why or why not**

# %% [markdown]
# No, We can’t  modify the tuples cause of in built feature of immutability that exists in tuple.

# %% [markdown]
# **16.What is a nested dictionary, and give an example of its use case**

# %% [markdown]
# The use of another dictionary in main dictionary used for clear understanding of values.
#
# Eg:
#
# A=101:{‘name’:’Balu’, ’age’: 26,’marks’:{‘maths’:26,’social’:56,’science’:98}},102:{‘name’:’Arjun’,’age’:25,’marks’:{‘maths’:86,’social’:96,’science’:78}}
#
# Here A is main dict and marks id nested dict.

# %% [markdown]
# **17.Describe the time complexity of accessing elements in a dictionary**

# %% [markdown]
# As there is no time complexity in dictionary of accessing elements cause of dict uses hash table of storing unique values in memory location to get picked up in easy and fast over large data sets in real world.

# %% [markdown]
# **18. In what situations are lists preferred over dictionaries**

# %% [markdown]
# Lists can be preferred over dictionaries
#
# a.      When you have duplicate values also to be allowed and used for result purpose.
#
# b.     If you want to in sequence/order of the elements to print sequentially these are the best options.

# %% [markdown]
# **19.Why are dictionaries considered unordered, and how does that affect data retrieval**

# %% [markdown]
# Dictionaries uses key and valued based elements to access means internally uses hash table to retrieve the values based on hash key.
#
# Hash table does not store in sequence the values instead store in bucket.
#
# It does not affect the access the data, infact it would do at fast rates cause of hash keys to get it.

# %% [markdown]
# **20.Explain the difference between a list and a dictionary in terms of data retrieval**

# %% [markdown]
# a.Time complexityà Listsà look for values, dictà look for keys only
#
# b.search by values à when ordered look for lists, at fast rateà dict we can choose
#
# c.Retrieve with indexà choose lists.
#
# d. duplicate values required and want to acquire themà lists.

# %% [markdown]
# **Practical Questions**

# %% [markdown]
# **1. Write a code to create a string with your name and print it**

# %%
s='Balu'
print(s)
# Out:
# Balu

# %% [markdown]
# **2. Write a code to find the length of the string "Hello World"**

# %%
b="Hello World"
print(len(b))
# Out:
# 11

# %% [markdown]
# **3. Write a code to slice the first 3 characters from the string "Python Programming"**

# %%
c= "Python Programming"
print(c[:3])
# Out:
# Pyt

# %% [markdown]
# **4. Write a code to convert the string "hello" to uppercase**

# %%
d="hello"
print(d.upper())
# Out:
# HELLO

# %% [markdown]
# **5. Write a code to replace the word "apple" with "orange" in the string "I like apple"**

# %%
f="I like apple"
print(f.replace('apple','orange'))
# Out:
# I like orange

# %% [markdown]
# **6. Write a code to create a list with numbers 1 to 5 and print it**

# %%
a=[]
for i in range(1,6):
  a.append(i)
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# **7. Write a code to append the number 10 to the list [1, 2, 3, 4]**

# %%
e=[1,2,3,4]
e.append(10)
e
# Out:
# [1, 2, 3, 4, 10]

# %% [markdown]
# **8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]**

# %%
r=[1,2,3,4,5]
r.remove(3)
r
# Out:
# [1, 2, 4, 5]

# %% [markdown]
# **9. Write a code to access the second element in the list ['a', 'b', 'c', 'd']**

# %%
p=['a', 'b', 'c', 'd']
p[1]
# Out:
# 'b'

# %% [markdown]
# **10. Write a code to reverse the list [10, 20, 30, 40, 50]**

# %%
e=[10,20,30,40,50]
e.reverse()
e
# Out:
# [50, 40, 30, 20, 10]

# %% [markdown]
# ***11.. Write a code to create a tuple with the elements 100, 200, 300 and print it.***

# %%
tup=(100,200,300)
tup
# Out:
# (100, 200, 300)

# %% [markdown]
# **12.. Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow')**

# %%
col=('red', 'green', 'blue', 'yellow')
col[1:]
# Out:
# ('green', 'blue', 'yellow')

# %% [markdown]
# **13. Write a code to find the minimum number in the tuple (10, 20, 5, 15)**

# %%
t=(10,20,5,15)
min(t)
# Out:
# 5

# %% [markdown]
# **14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit')**

# %%
animals=('dog', 'cat', 'rabbit')
animals.index('cat')
# Out:
# 1

# %% [markdown]
# **15. Write a code to create a tuple containing three different fruits and check if "kiwi" is in it**

# %%
fruits=('apple','banana','guava','Kiwi')
'Kiwi' in fruits
# Out:
# True

# %% [markdown]
# **16. Write a code to create a set with the elements 'a', 'b', 'c' and print it**

# %%
d={'a', 'b', 'c'}
d
type(d)
# Out:
# set

# %% [markdown]
# **17. Write a code to clear all elements from the set {1, 2, 3, 4, 5}**

# %%
num={1, 2, 3, 4, 5}
num.clear()
num
# Out:
# set()

# %% [markdown]
# **18. Write a code to remove the element 4 from the set {1, 2, 3, 4}**

# %%
set1={1,2,3,4}
set1.remove(4)
set1
# Out:
# {1, 2, 3}

# %% [markdown]
# **19. Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}**

# %%
a={1, 2, 3}
b={3,4,5}
a.union(b)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# **20. Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}**

# %%
c={1,2,3}
d={2,3,4}
c.intersection(d)
# Out:
# {2, 3}

# %% [markdown]
# **21.  Write a code to create a dictionary with the keys "name", "age", and "city", and print it.**

# %%
dic={'name':'Balu','age':35,'city':'Bangalore'}
dic
dic.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %% [markdown]
# **22.Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}**

# %%
rit={'name': 'John', 'age': 25}
rit["country",'college']='USA','mits'
rit['place']='tpt'
rit
# Out:
# {'name': 'John',
#  'age': 25,
#  ('country', 'college'): ('USA', 'mits'),
#  'place': 'tpt'}

# %% [markdown]
# **23.Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}**

# %%
a={'name': 'Alice', 'age': 30}
a['name']
# Out:
# 'Alice'

# %% [markdown]
# **24.Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}**

# %%
c= {'name': 'Bob', 'age': 22, 'city': 'New York'}
del c['age']
c
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %% [markdown]
# **25. Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}**

# %%
b={'name': 'Alice', 'city': 'Paris'}
'city' in b
# Out:
# True

# %% [markdown]
# **26.Write a code to create a list, a tuple, and a dictionary, and print them all.**

# %%
d=[10,20,30,40]
e=(40,50,60,70)
f={'name':'balu','age':24}
print(d,e,f)
# Out:
# [10, 20, 30, 40] (40, 50, 60, 70) {'name': 'balu', 'age': 24}

# %% [markdown]
# ***27.Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the
# result.(replaced)***

# %%
import random
nums=[random.randint(1,100) for i in range(5)]
nums
# Out:
# [47, 72, 76, 91, 72]

# %%
nums.sort()
nums
# Out:
# [47, 72, 72, 76, 91]

# %% [markdown]
# **28. Write a code to create a list with strings and print the element at the third index.**

# %%
f=['apple','guva','grape','lemon']
f[3]
# Out:
# 'lemon'

# %% [markdown]
# **29.Write a code to combine two dictionaries into one and print the result.**

# %%
a1={'a':1,'b':2}
b1={'c':3,'d':4}
a1.update(b1)
a1
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# **30. Write a code to convert a list of strings into a set.**

# %%
r=['darling','chava','lava']
p=set(r)
p
# Out:
# {'chava', 'darling', 'lava'}
