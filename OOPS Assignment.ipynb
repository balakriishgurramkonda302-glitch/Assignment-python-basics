# %% [markdown]
# **What is Object-Oriented Programming (OOP)**
#
# In the name itself indicates that programming can be done through object initialization for class and runs through it.

# %% [markdown]
# **What is a class in OOP**
#
# It is collection of functions under one category and it is easy to handle large data sets .
#
# Blueprint for objects: A class specifies what data (fields/attributes) and functions (methods) an object will contain
#
# Encapsulation of data and behavior: It binds together variables and functions so they can be managed as a single unit.

# %% [markdown]
# **What is an object in OOP**
#
# It is instance of class and it contains all blueprint of all methods and variables inside it.
#
# It represents a real-world entity in code, allowing programmers to model systems more naturally.

# %% [markdown]
# **What is the difference between abstraction and encapsulation**
#
# Definition:
#
# Abstraction: Focuses on what an object does, not how it does it.
#
# Encapsulation: Focuses on how data and methods are wrapped together in a single unit.
#
# Purpose:
#
# Abstraction: To hide implementation details and expose only necessary functionality.
#
# Encapsulation: To protect data by controlling access and ensuring integrity.
#
# Ex:
#
# A Car class exposes drive() without revealing the internal engine logic
#
# A Car class keeps fuelLevel private and provides refuel() method to modify it safely.

# %% [markdown]
# **What are dunder methods in Python**
#
# Dunder methods (short for “double underscore methods”) in Python are special methods that start and end with double underscores (__method__). They allow you to define how objects of your class behave with built-in operations like printing, arithmetic, comparisons, iterations.

# %% [markdown]
# **Explain the concept of inheritance in OOP**
#
# It is the concept of getting the methods and variables from parent class to child class but not reverse.

# %% [markdown]
# **What is polymorphism in OOP**
#
# Polymorphism in Object-Oriented Programming (OOP) is the ability of different classes to provide different implementations of the same interface or method based on the  parameters passed and it functions differently based on that for same method in the class.

# %% [markdown]
# **How is encapsulation achieved in Python**
#
# Encapsulation in Python is achieved by restricting direct access to class attributes and methods and controlling how they are used through well-defined interfaces. It’s one of the pillars of OOP that helps protect data and maintain clean design.

# %% [markdown]
# **What is a constructor in Python**
#
# A constructor in Python is a special method used to initialize objects when they are created from a class

# %% [markdown]
# **What are class and static methods in Python**
#
# Class method is directly refers to class and always starts with cls as its first attribute and it does not require object to access it.
#
# Static method does not require cls or self variables to trigger it. Remain all features all similar to class methods.

# %% [markdown]
# **What is method overloading in Python**
#
# It is part of Polymorphism topic.
#
# Method overloading in Python refers to defining multiple methods with the same name but different parameters within same class.

# %% [markdown]
# **What is method overriding in OOP**
#
# Method overriding in Object-Oriented Programming (OOP) occurs when a subclass provides its own implementation of a method that is already defined in its parent (superclass).It occurs in different classes inherited.

# %% [markdown]
# **What is a property decorator in Python**
#
# A property decorator in Python (@property) is a built-in feature that allows you to define methods in a class that can be accessed like attributes.

# %% [markdown]
# **Why is polymorphism important in OOP**
#
# Code Reusability: You can write generic code that works with different object types. For example, a function that calls speak() on an Animal object will work for Dog, Cat, or any other subclass without modification.
#
# Flexibility: Objects of different classes can be treated uniformly, even though they behave differently. This allows developers to design systems that adapt easily to new requirements.

# %% [markdown]
# **What is an abstract class in Python**
#
# An abstract class in Python is a class that serves as a blueprint for other classes. It can define methods that must be implemented by any subclass, but it cannot be instantiated directly.
#
# Abstract classes are used to enforce a contract: they specify what methods a subclass should have, without providing full implementations.

# %% [markdown]
# **What are the advantages of OOP**
#
# Inheritance, abstraction, encapsulation, polymorphism of all concepts advantages together and code reusability and scalabilty. Security and productivity also plays a major role.

# %% [markdown]
# **What is the difference between a class variable and an instance variable**
#
# Class var: Variables that are shared across all instances of a class and it belongs to class itself not to any object.
#
# Instance var: it can modify based on the instance that passed in the class and not belongs to class.

# %% [markdown]
# **What is multiple inheritance in Python**
#
# The inherited class has the opportunity to take all variables and methods from both/many parent classes and it leads to complexity to achieve this.

# %% [markdown]
# **Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python**
#
# __STR__
#
#  Human-readable representation
#
# Called when you use print(obj) or str(obj). When you include a function with strings it prints out the obj that to only strings. It is used for friendly reading.print(obj)
#
#  __REPR__
#
# Developer/debugging representation
#
# Called when you use repr(obj) or just type the object in an interactive shell.
#
# It is used for precide description for developers.print(repr(obj))

# %% [markdown]
# **What is the significance of the ‘super()’ function in Python**
#
# The super() function in Python is significant because it allows you to call methods from a parent (superclass) inside a child (subclass). It’s especially useful in inheritance hierarchies.

# %% [markdown]
# **What is the significance of the __del__ method in Python**
#
# The __del__ method in Python is a special (dunder) method known as the destructor. Its significance lies in defining what should happen when an object is about to be destroyed.

# %% [markdown]
# **What is the difference between @staticmethod and @classmethod in Python**
#
# Static method:
#
# Definition: Defines a method that does not depend on the class or instance.
#
# First argument: Takes no special first argument (self or cls).
#
# Usage: Acts like a regular function but is placed inside a class for logical grouping.
#
# Access: Cannot access or modify class or instance attributes.
#
# Decorator: @staticmethod
#
# Class method:
#
# Definition: Defines a method that receives the class itself as the first argument.
#
# First argument: cls (represents the class).
#
#  Usage: Often used for alternative constructors or operations that affect the class as a whole.
#
# Access: Can access and modify class-level variables.
#
# Decorator: @classmethod

# %% [markdown]
# **How does polymorphism work in Python with inheritance**
#
# Parent class defines a method → A base class provides a general implementation.
#
# Child class overrides the method → Subclasses redefine the method to provide specialized behavior.
#
# Polymorphic behavior at runtime → When you call the method on an object, Python decides which version to execute based on the object’s actual type, not the reference type.

# %% [markdown]
# **What is method chaining in Python OOP**
#
# Method chaining in Python OOP is a technique where multiple methods are called on the same object in a single line, one after another.

# %% [markdown]
# **What is the purpose of the __call__ method in Python?**
#
# The __call__ method in Python is a special (dunder) method that allows an object (instance of a class) to be called like a function

# %% [markdown]
# ** Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!"**

# %%
class Animal:
    def speak(self):
        print("The animal makes a sound.")


class Dog(Animal):
    def speak(self):
        print("Bark!")


animal = Animal()
dog = Dog()


animal.speak()
dog.speak()
# Out:
# The animal makes a sound.
# Bark!

# %% [markdown]
# ** Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.**

# %%
from abc import ABC, abstractmethod


class Shape(ABC):

    @abstractmethod
    def area(self):
        pass


class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14159 * self.radius * self.radius


class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


c = Circle(5)
rectangle = Rectangle(4, 6)


print("Circle Area:", c.area())
print("Rectangle Area:", rectangle.area())
# Out:
# Circle Area: 78.53975
# Rectangle Area: 24

# %% [markdown]
# ** Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute**

# %%
class Vehicle:
    def __init__(self, vehicle_type):
        self.type1 = vehicle_type

class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery):
        super().__init__(vehicle_type, brand)
        self.battery = battery


ev = ElectricCar("Four Wheeler", "Tesla", "75 kWh")


print("Type:", ev.type1)
print("Brand:", ev.brand)
print("Battery:", ev.battery)
# Out:
# Type: Four Wheeler
# Brand: Tesla
# Battery: 75 kWh

# %% [markdown]
# **Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method**

# %%
class Bird:
    def fly(self):
        print("The bird can fly.")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high in the sky.")

class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly, it swims instead.")

birds = [Sparrow(), Penguin()]

for bird in birds:
    bird.fly()
# Out:
# Sparrow flies high in the sky.
# Penguin cannot fly, it swims instead.

# %% [markdown]
#  -**Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.**

# %%
class BankAccount:
    def __init__(self, balance=0):

        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ₹{amount}")
        else:
            print("Deposit amount must be positive")

    def withdraw(self, amount):
        if amount <= 0:
            print("Withdrawal amount must be positive")
        elif amount > self.__balance:
            print("Insufficient balance")
        else:
            self.__balance -= amount
            print(f"Withdrawn: ₹{amount}")


    def check_balance(self):
        print(f"Current Balance: ₹{self.__balance}")

account = BankAccount(1000)
account.deposit(500)
account.withdraw(300)
account.check_balance()
# Out:
# Deposited: ₹500
# Withdrawn: ₹300
# Current Balance: ₹1200

# %% [markdown]
#  **Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play()**

# %%
class Instrument:
    def play(self):
        print("Instrument is playing")


class Guitar(Instrument):
    def play(self):
        print("Guitar is playing strings")


class Piano(Instrument):
    def play(self):
        print("Piano is playing keys")


instruments = [Guitar(), Piano()]

for instrument in instruments:
    instrument.play()
# Out:
# Guitar is playing strings
# Piano is playing keys

# %% [markdown]
# **Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers**

# %%
class MathOperations:


    @classmethod
    def add_numbers(cls, a, b):
        return a + b


    @staticmethod
    def subtract_numbers(a, b):
        return a - b



print("Addition:", MathOperations.add_numbers(10, 5))
print("Subtraction:", MathOperations.subtract_numbers(10, 5))
# Out:
# Addition: 15
# Subtraction: 5

# %% [markdown]
# **Implement a class Person with a class method to count the total number of persons created.**

# %%
class Person:

    total_persons = 0

    def __init__(self, name):
        self.name = name

        Person.total_persons += 1


    @classmethod
    def get_total_persons(cls):
        return cls.total_persons
p1 = Person("Ravi")
p2 = Person("Anil")
p3 = Person("Suresh")
Person.get_total_persons()
# Out:
# 3

# %% [markdown]
# **Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator"**

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator


    def __str__(self):
        return f"{self.numerator}/{self.denominator}"



f = Fraction(3, 4)


print(f)
# Out:
# 3/4

# %% [markdown]
# **10.. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.**

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    # Overloading + operator
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"


# Create vector objects
v1 = Vector(2, 3)
v2 = Vector(4, 5)

# Add vectors
v3 = v1 + v2

# Print result
print(v3)
# Out:
# (6, 8)

# %% [markdown]
# **Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."**

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")



p = Person("Ravi", 25)


p.greet()
# Out:
# Hello, my name is Ravi and I am 25 years old.

# %% [markdown]
# **Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.**

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        if not self.grades:
            return 0
        return sum(self.grades) / len(self.grades)



s1 = Student("Anil", [85, 90, 78, 92])

print("Student Name:", s1.name)
print("Average Grade:", s1.average_grade())
# Out:
# Student Name: Anil
# Average Grade: 86.25

# %% [markdown]
# **Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.**

# %%
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


r = Rectangle()

r.set_dimensions(5, 4)

print("Area of Rectangle:", r.area())
# Out:
# Area of Rectangle: 20

# %% [markdown]
# ** Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.**

# %%
class Employee:
    def __init__(self, hours_worked, hourly_rate):
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate



class Manager(Employee):
    def __init__(self, hours_worked, hourly_rate, bonus):
        super().__init__(hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus


emp1 = Employee(40, 500)
mgr = Manager(40, 500, 10000)

print("Employee Salary:", emp1.calculate_salary())
print("Manager Salary:", mgr.calculate_salary())
# Out:
# Employee Salary: 20000
# Manager Salary: 30000

# %% [markdown]
# **Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.**

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity



p = Product("Laptop", 50000, 2)

print("Product Name:", p.name)
print("Total Price:", p.total_price())
# Out:
# Product Name: Laptop
# Total Price: 100000

# %% [markdown]
# ** Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.**

# %%
from abc import ABC, abstractmethod


class Animal(ABC):

    @abstractmethod
    def sound(self):
        pass



class Cow(Animal):
    def sound(self):
        print("Cow says Moo")


class Sheep(Animal):
    def sound(self):
        print("Sheep says Baa")


cow = Cow()
sheep = Sheep()

cow.sound()
sheep.sound()
# Out:
# Cow says Moo
# Sheep says Baa

# %% [markdown]
# ** Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.**

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year Published: {self.year_published}"



b = Book("Wings of Fire", "A. P. J. Abdul Kalam", 1999)

print(b.get_book_info())
# Out:
# Title: Wings of Fire, Author: A. P. J. Abdul Kalam, Year Published: 1999

# %% [markdown]
# ** Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.**

# %%
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price



class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms



m1= Mansion("Banjara Hills, Hyderabad", 50000000, 10)

print("Address:", m1.address)
print("Price:", m1.price)
print("Number of Rooms:", m1.number_of_rooms)
# Out:
# Address: Banjara Hills, Hyderabad
# Price: 50000000
# Number of Rooms: 10
